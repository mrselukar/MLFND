# %% [markdown]
# # Project: Investigate a Dataset (Non-Renewable Energy Sources)
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
# > <ul>
# > <li>This Project sheds a light on the Non-Renewable Energy Sources Usages by the country and also the Co2 Emissions
# > <li>It trys to explore the recent history of Non-renewable energy sources namely oil and coal.</li>
# > <li>While exploring the usage of energy it also explores the  pollution caused in the form of CO2 Emissions </li>
# > <li>The Data is collected from www.gapminder.org/data  </li>
# > <li><b>This project was done as a part of Udacity Indias MLFND Course by Mayur Selukar (@mrselukar) <b></li>
# <br><br>
# > <b>Cheers  </b><br><br>
# > <b>NOTE</b> Resources are mentioned near usage in Comments

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as ff
py.offline.init_notebook_mode(connected=True)
# %pylab inline
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# Populating the interactive namespace from numpy and matplotlib

# %%
# https://www.youtube.com/watch?v=XUNaGFa9xCM
# resource for plotly
def print_df(data_f):
    """
    Nicely prints a dataframe
    """
    index_name = d_frame.index.name
    for i in range (1,len(index_name)):
        if i % 15 == 0 :
            index_name = index_name[:i] + '<br>' + index_name[i:]
            i = i+4
    table = ff.create_table(data_f,index=True,index_title = index_name,height_constant=60)
    table.layout.width=145*len(data_f.columns)
    py.offline.iplot(table)

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# ### General Properties
# > The data collected was from BP and CDIAC in both case each row represents a country and the columns give the reading for countries for that year.
# > If a reading is missing its either a NaN or a "-"
# #### Whats done.
# > All the data is loaded into various data frames
# > Index is set as Int64
# > Data is converted to numerica type
# > Index is set as the country Name

# %%
"""
data_links is the 
"""
data_links = {'coal_consumption_per_capita' : './csv_data/Coal Consumption per capita.xls.csv',
             'coal_consumption_total':'./csv_data/Coal Consumption.xls.csv',
             'co2_per_capita' : './csv_data/carbon_dioxide_emissions_per_capita.csv',
             'co2_total':'./csv_data/carbon_dioxide_total_emissions.csv',
             'oil_consumption_per_capita':'./csv_data/Oil Consumption per capita.xls.csv',
             'oil_consumption_total':'./csv_data/Oil Consumption.xls.csv',
             'oil_production_total':'./csv_data/Oil Production.xls.csv',
             'oil_production_per_capita':'./csv_data/Oil Production per capita.xls.csv',
             'oil_reserves_per_capita':'./csv_data/Oil Proved reserves per capita.csv',
             'oil_reserves_total':'./csv_data/Oil Proved reserves.xls.csv'}

# %%
df = {} # a dictionaries of data_frames
"""
Loading the data in to data frames
"""
for name,link in data_links.items():
    df[name] = pd.read_csv(link)
    # listing the column names 
    col_headders = list(df[name].columns.values)
    # setting the index of each row to be the country name 
    df[name].set_index(col_headders[0],inplace=True)    
## All the data is in tonns per year

# %% [markdown]
# ### Data Cleaning (Removing the empty data and filling NaNs for unexpected entries)
# #### Also type casting the data to a numeric type for operating on it

# %%
for name,d_frame in df.items():
    ### for each column in every df we make the data type as f64 and set all the exceptions as NaNs
    ### The exception in this case were the empty records initialized as '-'
    df[name] = d_frame.apply(pd.to_numeric,errors='coerce')
    d_frame = d_frame.replace([0,'-'],np.NaN)
    # setting the cloumn indexes as ints from strings
    d_frame.columns = d_frame.columns.astype(int)
    # This Reassignment is necessary  or else the column name remains strings
    df[name] = d_frame

# %% [markdown]
# ### Data Cleaning
# > Trimming the data
# > Adding missing columns
# > Dropping Countries Where less than 20 years of data is present

# %%
for name,d_frame in df.items():
    #print name
    drop_list = [x for x in d_frame.columns if x < 1980 or x > 2010 ]
    d_frame.drop(drop_list,axis = 1,inplace =True)
    d_frame.replace(0,np.NaN, inplace =True)
    col_names = d_frame.columns
    # Dropping coutries with less than 20 years of data
    d_frame.dropna(thresh=20, inplace = True)
    req_columns = range(1980,2011,1)
    for x in req_columns:  
        if not x in col_names:
            d_frame[x] = np.nan

# %% [markdown]
# ### Adding units to the index column name

# %%
df['co2_per_capita'].index.name = df['co2_per_capita'].index.name+"<br>(Tonnes per Year)"
df['co2_total'].index.name = df['co2_total'].index.name+"<br>(Tonnes per Year)"

# %% [markdown]
# ### Helper Functions
# > Before exploring the questions some helper functions need to be created
# > <ol>
# > <li>add_averages(d_frame)
# >> Add an average column (Labled: 0) and index (Labled: 'Global') to df
# >> http://www.datadan.io/python-pandas-pitfalls-hard-lessons-learned-over-time/
# > </li>
# > <li>def plot_line_graph(data_f):
# >> Plots line graph for the given dadta frame
# >> The df.columns are the points on xaxis
# >> Quantity represented on y axis
# > </li>

# %%
"""
Add an average column and index to df
http://www.datadan.io/python-pandas-pitfalls-hard-lessons-learned-over-time/
"""
def add_averages(data_f):
    new_row = data_f.mean(axis=0)
    new_col = data_f.mean(axis=1)
    #print new_col
    data_f.loc['Global Average'] = new_row
    data_f[0] = new_col

# %%
def plot_line_graph(data_f):
    # Adding graph data
    years = list(data_f.columns)
    # removing the zero (indiacting total)
    try:
        years.remove(0)
    except:
        print "Warning The zero Column was not found"
    # each row corrosponds to 1 trace on th line graph
    trace_data = []
    for index,row in data_f.iterrows():
        country = index 
        data = row
        trace = go.Scatter(
                        x=years,
                        y=data, 
                        xaxis='Year', 
                        yaxis=data_f.index.name,
                        mode='lines+markers',
                        name=country,
                        marker = dict(
                            size = 7,
                            line = dict(
                            width = 0,
                                )
                            )
                        )
        trace_data.append(trace)
    my_layout = dict(
                    title = 'Top Countries '+ data_f.index.name,
                    hovermode= 'closest',
                    yaxis = dict(
                                    zeroline = True,
                                    title= data_f.index.name,
                                    ticklen= 5
                                ),
                    xaxis = dict(
                                    zeroline = True,
                                    title= 'Years',
                                    ticklen= 5
                                )
             )

    figure = dict(data=trace_data, layout=my_layout)
    py.offline.iplot(figure)

# %%
def plot_pie(ser):
    """
    Takes a series as and input and plots a pie chart of it 
    """
    # Adding graph data
    # removing the global row(indiacting total)
    try:
        my_ser = ser.drop(['Global Average'],axis = 0)
    except:
        print "Warning The Global Average Row was not found"
    # each row corrosponds to 1 slice of pie
    trace_data = []
    lables = []
    i = 0
    rest_sum = 0
    for index,row in my_ser.iteritems():
        if i < 7 :
            country = index 
            data = row            
            trace_data.append(data)
            lables.append(country)
            i +=1
        else:
            rest_sum += row
            i +=1
    trace_data.append(rest_sum)
    lables.append('Rest of the World')
    
    fig = {
      "data": [
                {
                    "values": trace_data,
                    "labels": lables,
                    "name": ser.index.name,
                    "hoverinfo":"label+percent+name",
                    "hole": .4,
                    "type": "pie"
                }
              ],
        
    "layout": {
                    "title":ser.index.name+"Average Over 30 years (1980-2010) ",
                    "annotations": [
                                        {
                                            "font": {"size": 20},
                                            "showarrow": False,
                                            "text": ser.index.name.split(" ")[0],
                                            #"x": 0.20,
                                            #"y": 0.5
                                        }
            
                                    ]
                }
    }


        
    
    py.offline.iplot(fig)

# %% [markdown]
# ### Reorganizing the data
# > 1. Addign average Columns
# > 2. Sorting the data based of the average over the 30 years

# %%
"""
This Cell Add the averages to each data frame 
"""
for name,d_frame in df.items():
    add_averages(d_frame)

# %%
"""
This Cell Sorts the data based on the column with index 0
ie the column representing the average over the 30 years 
The Global Average Row is not sorted and remains at the bottom
"""
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_values.html
for name,d_frame in df.items():
    d_frame.drop(['Global Average'],axis = 0)
    d_frame.sort_values(by = [0],ascending = False,inplace = True,na_position = 'first')

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
# ### Q1. Who are the Top Consumers of Oil how do they compare to global average?
# > This Explores the Top Consumers per capita and as a nation.

# %%
def explore_df(data_f):
    #print_df(data_f.ix[:7,:])
    plot_line_graph(data_f.ix[:7,:])

# %%
explore_df(df['oil_consumption_per_capita'])
# Out:
# <div id="7ac49795-0102-4885-96ac-7b6b49fa2055" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7ac49795-0102-4885-96ac-7b6b49fa2055", [{"name": "Global Average", "yaxis": "Oil Consumption per capita (tonnes per year)", "marker": {"line": {"width": 0}, "size": 7}, "mode": "lines+markers", "xaxis": "Year", "y": [1.4293386241593053, 1.3987594720032026, 1.3477074244477247, 1.3113654582703804, 1.3016369431438772, 1.3518309795115762, 1.3912520436229223, 1.3885857281612548, 1.383244947358094, 1.3946763523365406, 1.4136377506844102, 1.4030779349822928, 1.4009615150695218, 1.3680293267188768, 1.408260823485918, 1.4120761559667752, 1.4095213440672671, 1.429273127855147, 1.4231485063251665, 1.4124449347811876, 1.399049736966536, 1.4225989126447947, 1.439824020415633, 1.4304673785592523, 1.4689829605596079, 1.494577182718034, 1.4859835805179056, 1.485457939558974, 1.4744393920330754, 1.464970142280311, 1.484085163676564, null], "x": [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2
980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010], "type": "scatter"}, {"name": "Kuwait", "yaxis": "Oil proved reserves total (tonnes)", "marker": {"line": {"width": 0}, "size": 7}, "mode": "lines+markers", "xaxis": "Year", "y": ["9265652000", "9238372000", "9159260000", "9138800000", "12645644000", "12612089600", "12892800800", "12893210000", "12893210000", "13247850000", "13234210000", "13162600000", "13162600000", "13162600000", "13162600000", "13162600000", "13162600000", "13162600000", "13162600000", "13162600000", 13162600000.0, 13162 ...

# %% [markdown]
# > Per Person reserves are on a downward spiral but the Total proven reserves are incereasing.
# This indiacates that there is an incerease in proven reserves but the population is growing faster.
# Most of the Oil Reservers are in Saudi Arabia, where as Kuwait and UAE have the most Oil reserves per person

# %% [markdown]
# ### Who is polluting the most?

# %%
explore_df(df['co2_per_capita'])
# Out:
# <div id="31df92b1-fc3f-4d13-9c63-5fbee11c53e2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("31df92b1-fc3f-4d13-9c63-5fbee11c53e2", [{"name": "Global Average", "yaxis": "CO2 per capita<br>(Tonnes per Year)", "marker": {"line": {"width": 0}, "size": 7}, "mode": "lines+markers", "xaxis": "Year", "y": [4.926742085023811, 4.373450879214285, 4.238146772142857, 4.073614401702382, 4.184540864708334, 4.28210314522024, 4.400564803905882, 4.428892918764708, 4.560822674564705, 4.751592016335292, 4.743076657290699, 4.6674153404767456, 4.715877800465116, 5.0136043035872095, 5.027585183540698, 5.024752037075585, 4.976517504491228, 5.038781592538009, 4.867892980105265, 4.876027546918127, 5.162951080755811, 5.122806057569767, 5.0676115008023235, 5.276082283069766, 5.380787107866279, 5.342877021633721, 5.334371001220929, 5.485250576104655, 5.367144551819766, 5.170508338517444, 5.265839476819767, null], "x": [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010], "type": "scatter"}, {"name": "Qatar", "yaxis": "CO2 per capita<br>(Tonnes per Year)", "marker": {"line": {"width": 0}, "size": 7}, "mode": "lines+markers", "xaxis": "Year", "y": [59.10509009, 52.32766338, 44.96578334, 36.75733396, 36.44289451, 33.70687797, 33.64680555, 27.37399756, 26.98982347, 31.14620679, 24.85353576, 36.59635914, 54.89440207, 62.51136163, 61.03631534, 61.47543436, 62.10311033, 68.61994212, 59.03245947, 55.10905996, 58.76400483, 49.92952963, 45.62677335, 55.32262178, 62.06937698, 63.1874356, 57.98689475, 57.0668165, 48.70206152, 41.37884274, 40.09833259, 48.671843453870956], "x": [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010], "type": "scatter"}, {"name": "United Arab Emirates", "yaxis": "CO2 per capita<br>(Tonnes per Year)", "marker": {"line": {"width": 0}, "size": 7}, "mode": "lines+markers", "xaxis": "Year", "y": [36.3120612, 33.74405112, 31.8562054, 29.0375707, 36.2707615, 37.00642451, 33.05622201, 31.44068605, 30.0159027, 31.87571962, 28.75324875, 29.84883678, 28.86225989, 31.09497523, 32.74741974, 30.07600328, 16.59496717, 15.94508113, 29.57288649, 27.05096263, 37.103126399999994, 32.19789338, 26.02284928, 31.41231635, 30.95380899, 28.53970008, 26.56463484, 25.78687314, 25.60501366, 23.43157057, 22.30940485, 29.389981852903226], "x": [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2
980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010], "type": "scatter"}, {"name": "China", "yaxis": "CO2 emission total<br>(Tonnes per Year)", "marker": {"line": {"width": 0}, "size": 7}, "mode": "lines+markers", "xaxis": "Year", "y": [1467059.0, 1451369.333, 1580117.0, 1666877.667, 1814743.333, 1966374.667, 2068781.0, 2209507.667, 2369286.333, 2408321.667, 2460520.333, 2584303.333, 2695737.0, 2878432.333, 3057963.333, 3319983.333, 3462774.333, 3469194.667, 3324042.333, 3317754.0, 3404870.333, 3487249.333, 3693906.333, 4524765.666999999, 5287685.333000001, 5789490.667, 6413880.0, 6791187.333, 7037070.333, 7686415.0, 8287717.256, 3612173.5565483873], "x": [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010], "type": "scatter"}, {"name": "Japan", "yaxis": "CO2 emission total<br>(Tonnes per Year)", "marker": {"line": {"width": 0}, "size": 7}, "mode": "lines+markers", "xaxis": "Year", "y": [998990.6667, 970713.3333, 939759.3333, 932044.6667, 988621.3333, 963790.6667, 967266.6667, 959478.6667, 1054236.3329999999, 1082917.0, 1094533.0, 1100425.3329999999, 1123459.3329999999, 1108462.6670000001, 1173920.0, 1183838.3329999999, 1205501.0, 1201522.6670000001, 1158960.0, 1197933.0, 1219482.0, 1202157.0, 1216640.3329999999, 1237280.0, 1259544.0, 1238068.3329999999, 1231186.0, 1251055.6670000001, 1207576.3329999999, 1101034.0, 1172280.544, 1120731.5551419354], "x": [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010], "type": "scatter"}, {"name": "India", "yaxis": "CO2 emission total<br>(Tonnes per Year)", "marker": {"line": {"width": 0}, "size": 7}, "mode": "lines+markers", "xaxis": "Year", ...

# %% [markdown]
# >> Per Person Quator is releasing the most CO2
# >> On the total CO2 emmited USA was at top till 2005 where China took over and is currently releasing most amount of CO2
# >> The Global Average was nearly constant till 2009 but is on an uprise

# %% [markdown]
# ### What are the trends over the whole period?
# >Pie Chart Refrence :https://plot.ly/python/pie-charts/

# %%
plot_pie(df['oil_consumption_total'][0])
# Out:
# <div id="f65a4368-fd53-44f9-9efc-5e8d3aed6229" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f65a4368-fd53-44f9-9efc-5e8d3aed6229", [{"name": "Oil Consumption total (tonnes per year)", "labels": ["United States", "Japan", "China", "Russia", "Germany", "France", "India", "Rest of the World"], "values": [844513550.8461539, 240014956.84615386, 216389412.65384614, 168120651.92307693, 127994769.23076923, 90889950.0, 90592115.38461539, 1410292390.5641026], "hoverinfo": "label+percent+name", "hole": 0.4, "type": "pie"}], {"annotations": [{"text": "Oil", "font": {"size": 20}, "showarrow": false}], "title": "Oil Consumption total (tonnes per year)Average Over 30 years (1980-2010) "}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
plot_pie(df['coal_consumption_total'][0])
# Out:
# <div id="62980a13-5059-433f-bfdb-69d12d0d8131" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("62980a13-5059-433f-bfdb-69d12d0d8131", [{"name": "Coal consumption total (tonnes oil equivalent)", "labels": ["China", "United States", "India", "Russia", "Germany", "Japan", "Poland", "Rest of the World"], "values": [736077358.336818, 500128898.9295722, 131066732.688774, 130377076.92307673, 106446923.77888103, 89912258.95235483, 75082386.41935481, 559110115.716951], "hoverinfo": "label+percent+name", "hole": 0.4, "type": "pie"}], {"annotations": [{"text": "Coal", "font": {"size": 20}, "showarrow": false}], "title": "Coal consumption total (tonnes oil equivalent)Average Over 30 years (1980-2010) "}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
plot_pie(df['oil_production_total'][0])
# Out:
# <div id="59172ab4-8174-457a-a2dd-4d5eded13903" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("59172ab4-8174-457a-a2dd-4d5eded13903", [{"name": "Crude oil production, total (toe)", "labels": ["Russia", "Saudi Arabia", "United States", "Iran", "Mexico", "China", "Venezuela", "Rest of the World"], "values": [432078682.94792295, 405939129.50875556, 396184796.0922595, 164373032.57035506, 157236117.95315427, 150556206.45161286, 135004067.83436978, 1449379397.4554467], "hoverinfo": "label+percent+name", "hole": 0.4, "type": "pie"}], {"annotations": [{"text": "Crude", "font": {"size": 20}, "showarrow": false}], "title": "Crude oil production, total (toe)Average Over 30 years (1980-2010) "}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
plot_pie(df['oil_reserves_total'][0])
# Out:
# <div id="bdb26cab-ebef-498f-b73a-5d9f24d658f7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("bdb26cab-ebef-498f-b73a-5d9f24d658f7", [{"name": "Oil proved reserves total (tonnes)", "labels": ["Saudi Arabia", "Iran", "Iraq", "Kuwait", "United Arab Emirates", "Venezuela", "Libya", "Rest of the World"], "values": [35949386977.77778, 17383725333.333332, 15648111111.11111, 13579377777.777779, 13339920000.0, 11440731866.666666, 5403046488.888889, 33840942894.444443], "hoverinfo": "label+percent+name", "hole": 0.4, "type": "pie"}], {"annotations": [{"text": "Oil", "font": {"size": 20}, "showarrow": false}], "title": "Oil proved reserves total (tonnes)Average Over 30 years (1980-2010) "}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
plot_pie(df['co2_total'][0])
# Out:
# <div id="111d6042-d3d2-4e69-a868-187a07849559" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("111d6042-d3d2-4e69-a868-187a07849559", [{"name": "CO2 emission total<br>(Tonnes per Year)", "labels": ["United States", "China", "Japan", "India", "Germany", "United Kingdom", "Canada", "Rest of the World"], "values": [5168303.234032257, 3612173.5565483873, 1120731.5551419354, 986312.5036483872, 908889.1938774192, 551432.7390709678, 477661.83202903223, 7472244.505346855], "hoverinfo": "label+percent+name", "hole": 0.4, "type": "pie"}], {"annotations": [{"text": "CO2", "font": {"size": 20}, "showarrow": false}], "title": "CO2 emission total<br>(Tonnes per Year)Average Over 30 years (1980-2010) "}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions

# %% [markdown]
# > The report visualizes the pattern of crude oil and coal consumption over the time period of 1980 to 2010
# > It answers the various question on consumption, production of the Non-Renewable energy surces.
# > It also explores the remaining proven reserves and the C02 emission by Countries

# %% [markdown]
# > Despite of various environment conservation efforts the Consumption of non-renewable energy is on the rise and the proven reserves/person are on the decline
# > Mean while the Co2 emissions are on the rise after a long time
# > This begs the question where are all the environment conservation efforts gone.

# %% [markdown]
# The Global trends over the past 30 years are visualized and indicate that China is rapidly taking the top position in Consumption or Non-Renuables and Co2 emissions (Total) where as initially it was the USA.
